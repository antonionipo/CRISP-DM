# %% [markdown]
# <a href="https://colab.research.google.com/github/antonionipo/CRISP-DM/blob/main/Data_Preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('DataPrepFinal.csv')
df_c = pd.read_csv('campaign.csv')
df_invest = pd.read_csv('invested.csv')

# %%
df.head()
# Out:
#    Unnamed: 0          ID                                               name  \
# 0           0  1000002330                    The Songs of Adelaide & Abullah
# 1           1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2           2  1000004038                                     Where is Hank?
# 3           3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4           4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency  deadline     goal        launched  \
# 0          Poetry    Publishing      GBP  09/10/15   100000  11/08/15 12:12
# 1  Narrative Film  Film & Video      USD  01/11/17  3000000  02/09/17 04:43
# 2  Narrative Film  Film & Video      USD  26/02/13  4500000  12/01/13 00:20
# 3           Music         Music      USD  16/04/12   500000  17/03/12 03:24
# 4    Film & Video  Film & Video      USD  29/08/15  1950000  04/07/15 08:35
#
#    pledged     state  backers country  usd pledged  usd_pledged_real  \
# 0        0    failed        0      GB          0.0                 0
# 1   242100    failed       15      US      10000.0            242100
# 2    22000    failed        3      US      22000.0             22000
# 3      100    failed        1      US        100.0               100
# 4   128300  canceled       14      US     128300.0            128300
#
#   usd_goal_real
# 0    USD 153395
# 1   USD 3000000
# 2   USD 4500000
# 3    USD 500000
# 4   USD 1950000

# %%
df = df.drop(columns=['Unnamed: 0', 'name', 'category', 'goal', 'usd pledged'], errors='ignore')
df.head()
# Out:
#            ID main_category currency  deadline        launched  pledged  \
# 0  1000002330    Publishing      GBP  09/10/15  11/08/15 12:12        0
# 1  1000003930  Film & Video      USD  01/11/17  02/09/17 04:43   242100
# 2  1000004038  Film & Video      USD  26/02/13  12/01/13 00:20    22000
# 3  1000007540         Music      USD  16/04/12  17/03/12 03:24      100
# 4  1000011046  Film & Video      USD  29/08/15  04/07/15 08:35   128300
#
#       state  backers country  usd_pledged_real usd_goal_real
# 0    failed        0      GB                 0    USD 153395
# 1    failed       15      US            242100   USD 3000000
# 2    failed        3      US             22000   USD 4500000
# 3    failed        1      US               100    USD 500000
# 4  canceled       14      US            128300   USD 1950000

# %%
df.dtypes
# Out:
# ID                   int64
# main_category       object
# currency            object
# deadline            object
# launched            object
# pledged              int64
# state               object
# backers              int64
# country             object
# usd_pledged_real     int64
# usd_goal_real       object
# dtype: object

# %%
df['usd_goal_real'] = df['usd_goal_real'].apply(lambda x: x.replace('USD ', ''))
df['usd_goal_real'] = df['usd_goal_real'].astype(int)
df.head()
# Out:
#            ID main_category currency  deadline        launched  pledged  \
# 0  1000002330    Publishing      GBP  09/10/15  11/08/15 12:12        0
# 1  1000003930  Film & Video      USD  01/11/17  02/09/17 04:43   242100
# 2  1000004038  Film & Video      USD  26/02/13  12/01/13 00:20    22000
# 3  1000007540         Music      USD  16/04/12  17/03/12 03:24      100
# 4  1000011046  Film & Video      USD  29/08/15  04/07/15 08:35   128300
#
#       state  backers country  usd_pledged_real  usd_goal_real
# 0    failed        0      GB                 0         153395
# 1    failed       15      US            242100        3000000
# 2    failed        3      US             22000        4500000
# 3    failed        1      US               100         500000
# 4  canceled       14      US            128300        1950000

# %%
df['launched'].str.replace(' \d\d:\d\d', '', regex=True)
df.head()
# Out:
#            ID main_category currency  deadline        launched  pledged  \
# 0  1000002330    Publishing      GBP  09/10/15  11/08/15 12:12        0
# 1  1000003930  Film & Video      USD  01/11/17  02/09/17 04:43   242100
# 2  1000004038  Film & Video      USD  26/02/13  12/01/13 00:20    22000
# 3  1000007540         Music      USD  16/04/12  17/03/12 03:24      100
# 4  1000011046  Film & Video      USD  29/08/15  04/07/15 08:35   128300
#
#       state  backers country  usd_pledged_real  usd_goal_real
# 0    failed        0      GB                 0         153395
# 1    failed       15      US            242100        3000000
# 2    failed        3      US             22000        4500000
# 3    failed        1      US               100         500000
# 4  canceled       14      US            128300        1950000

# %%
df['usd_goal_real'] = df['usd_goal_real'].astype('int64')
df.head()
# Out:
#            ID main_category currency  deadline        launched  pledged  \
# 0  1000002330    Publishing      GBP  09/10/15  11/08/15 12:12        0
# 1  1000003930  Film & Video      USD  01/11/17  02/09/17 04:43   242100
# 2  1000004038  Film & Video      USD  26/02/13  12/01/13 00:20    22000
# 3  1000007540         Music      USD  16/04/12  17/03/12 03:24      100
# 4  1000011046  Film & Video      USD  29/08/15  04/07/15 08:35   128300
#
#       state  backers country  usd_pledged_real  usd_goal_real
# 0    failed        0      GB                 0         153395
# 1    failed       15      US            242100        3000000
# 2    failed        3      US             22000        4500000
# 3    failed        1      US               100         500000
# 4  canceled       14      US            128300        1950000

# %%
df['launched'] = df['launched'].str.replace(' \d\d:\d\d', '', regex=True)
df['deadline'] = pd.to_datetime(df['deadline'], format='%d/%m/%y')
df['launched'] = pd.to_datetime(df['launched'], format='%d/%m/%y')
df.dtypes
# Out:
# ID                           int64
# main_category               object
# currency                    object
# deadline            datetime64[ns]
# launched            datetime64[ns]
# pledged                      int64
# state                       object
# backers                      int64
# country                     object
# usd_pledged_real             int64
# usd_goal_real                int64
# dtype: object

# %%
df['time_range'] = (df['deadline'] - df['launched']).dt.days
df['time_range'] = df['time_range'].astype('int64')
df.head()
# Out:
#            ID main_category currency   deadline   launched  pledged     state  \
# 0  1000002330    Publishing      GBP 2015-10-09 2015-08-11        0    failed
# 1  1000003930  Film & Video      USD 2017-11-01 2017-09-02   242100    failed
# 2  1000004038  Film & Video      USD 2013-02-26 2013-01-12    22000    failed
# 3  1000007540         Music      USD 2012-04-16 2012-03-17      100    failed
# 4  1000011046  Film & Video      USD 2015-08-29 2015-07-04   128300  canceled
#
#    backers country  usd_pledged_real  usd_goal_real  time_range
# 0        0      GB                 0         153395          59
# 1       15      US            242100        3000000          60
# 2        3      US             22000        4500000          45
# 3        1      US               100         500000          30
# 4       14      US            128300        1950000          56

# %%
df_c.head()
# Out:
#            ID  Text Description  Video  Image  Infographic  Reviews  Risks
# 0  1000002330                 1      1      1            1        0      1
# 1  1000003930                 1      1      1            1        1      0
# 2  1000004038                 1      0      1            1        0      1
# 3  1000007540                 1      1      0            1        0      0
# 4  1000011046                 1      0      1            0        0      0

# %%
df_c['Text Description'].drop(columns=['Text Description'])
df_c.head()
# Out:
#            ID  Text Description  Video  Image  Infographic  Reviews  Risks
# 0  1000002330                 1      1      1            1        0      1
# 1  1000003930                 1      1      1            1        1      0
# 2  1000004038                 1      0      1            1        0      1
# 3  1000007540                 1      1      0            1        0      0
# 4  1000011046                 1      0      1            0        0      0

# %%
df = df.merge(df_c, how='right', on='ID')
df.head()
# Out:
#            ID main_category currency   deadline   launched  pledged     state  \
# 0  1000002330    Publishing      GBP 2015-10-09 2015-08-11        0    failed
# 1  1000003930  Film & Video      USD 2017-11-01 2017-09-02   242100    failed
# 2  1000004038  Film & Video      USD 2013-02-26 2013-01-12    22000    failed
# 3  1000007540         Music      USD 2012-04-16 2012-03-17      100    failed
# 4  1000011046  Film & Video      USD 2015-08-29 2015-07-04   128300  canceled
#
#    backers country  usd_pledged_real  usd_goal_real  time_range  \
# 0        0      GB                 0         153395          59
# 1       15      US            242100        3000000          60
# 2        3      US             22000        4500000          45
# 3        1      US               100         500000          30
# 4       14      US            128300        1950000          56
#
#    Text Description  Video  Image  Infographic  Reviews  Risks
# 0                 1      1      1            1        0      1
# 1                 1      1      1            1        1      0
# 2                 1      0      1            1        0      1
# 3                 1      1      0            1        0      0
# 4                 1      0      1            0        0      0

# %%
df_invest.head()
# Out:
#            ID backedLocation  age
# 0  1000003930             BR   18
# 1  1000004038             US   57
# 2  1000007540             US   43
# 3  1000011046             BR   29
# 4  1000014025             BR   77

# %%
df_invest.sort_values(by=['ID'])
# Out:
#                ID backedLocation  age
# 27400      106144             US   63
# 10585      106144            GBK   70
# 17409     1003381             BR   68
# 594       1003381             US   29
# 2925      1017454             US   62
# ...           ...            ...  ...
# 16812  1098729640            GBK   61
# 33627  1098729640            GBK   43
# 16814  1098735707             BR   66
# 33629  1098735707             US   62
# 35395  1098735707             US   63
#
# [35396 rows x 3 columns]

# %%
df_invest = pd.get_dummies(df_invest, columns=['backedLocation'])
df_invest.sort_values(by=['ID'])
# Out:
#                ID  age  backedLocation_BR  backedLocation_GBK  \
# 27400      106144   63              False               False
# 10585      106144   70              False                True
# 17409     1003381   68               True               False
# 594       1003381   29              False               False
# 2925      1017454   62              False               False
# ...           ...  ...                ...                 ...
# 16812  1098729640   61              False                True
# 33627  1098729640   43              False                True
# 16814  1098735707   66               True               False
# 33629  1098735707   62              False               False
# 35395  1098735707   63              False               False
#
#        backedLocation_US
# 27400               True
# 10585              False
# 17409              False
# 594                 True
# 2925                True
# ...                  ...
# 16812              False
# 33627              False
# 16814              False
# 33629               True
# 35395               True
#
# [35396 rows x 5 columns]

# %%
df_invest = df_invest.groupby(by=['ID']).agg({'age':'mean', 'backedLocation_BR':'sum',  'backedLocation_GBK':'sum', 'backedLocation_US':'sum', })

# %%
df = df.merge(df_invest, how='right', on='ID')
df.head()
# Out:
#         ID main_category currency   deadline   launched  pledged       state  \
# 0   106144         Music      USD 2014-06-15 2014-05-16     1500      failed
# 1  1003381         Music      USD 2012-07-19 2012-06-21   115900      failed
# 2  1017454  Film & Video      USD 2015-04-26 2015-04-20    16700  successful
# 3  1024013    Publishing      USD 2012-05-18 2012-04-03   975805      failed
# 4  1024208    Technology      USD 2014-09-11 2014-08-12    15000      failed
#
#    backers country  usd_pledged_real  ...  Text Description  Video  Image  \
# 0        1      US              1500  ...                 1      1      1
# 1       30      US            115900  ...                 1      0      1
# 2        9      US             16700  ...                 1      1      0
# 3      136      US            975805  ...                 1      1      1
# 4        5      US             15000  ...                 1      0      1
#
#    Infographic  Reviews  Risks   age  backedLocation_BR  backedLocation_GBK  \
# 0            0        0      1  66.5                  0                   1
# 1            0        1      1  48.5                  1                   0
# 2            1        0      1  41.5                  0                   0
# 3            1        0      0  77.0                  2                   0
# 4            1        0      0  71.0                  0                   1
#
#    backedLocation_US
# 0                  1
# 1                  1
# 2                  2
# 3                  0
# 4                  1
#
# [5 rows x 22 columns]
